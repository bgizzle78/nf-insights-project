# %% [markdown]
# BEA SAGDP2 WV data cleaning and exploration.

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Read in data
sagdp2wv_df = pd.read_csv('../../../workspace/nf-insights-project/data_raw/BEA GDP Data/SAGDP2_WV_1997_2024.csv', low_memory=False)
print('CSV read successfully!')

sagdp2wv_df.head()
# Out:
# CSV read successfully!
#     GeoFIPS        GeoName  Region TableName  LineCode IndustryClassification  \
# 0   "54000"  West Virginia     5.0    SAGDP2       1.0                    ...
# 1   "54000"  West Virginia     5.0    SAGDP2       2.0                    ...
# 2   "54000"  West Virginia     5.0    SAGDP2       3.0                     11
# 3   "54000"  West Virginia     5.0    SAGDP2       4.0                111-112
# 4   "54000"  West Virginia     5.0    SAGDP2       5.0                113-115
#
#                                      Description                         Unit  \
# 0                            All industry total   Millions of current dollars
# 1                            Private industries   Millions of current dollars
# 2    Agriculture, forestry, fishing and hunting   Millions of current dollars
# 3                                         Farms   Millions of current dollars
# 4     Forestry, fishing, and related activities   Millions of current dollars
#
#       1997     1998  ...     2015     2016     2017     2018     2019  \
# 0  38781.2  40258.9  ...  71713.4  71248.9  75172.4  79794.3  80242.4
# 1  32787.1  34074.5  ...  59992.8  59614.8  63338.1  67602.0  67569.3
# 2    231.8    223.7  ...    343.3    319.8    389.1    355.7    355.4
# 3    103.2    106.2  ...    203.5    177.0    246.7    216.4    216.2
# 4    128.5    117.5  ...    139.8    142.7    142.4    139.3    139.2
#
#       2020     2021     2022      2023      2024
# 0  77536.5  87178.8  98824.1  101479.9  106475.1
# 1  64173.0  73238.4  84607.7   86604.2   90908.8
# 2    275.2    376.3    669.5     463.1     560.9
# 3    148.5    246.9    537.5     330.3     424.1
# 4    126.7    129.4    132.0     132.9     136.9
#
# [5 rows x 36 columns]

# %%
# Get column names
sagdp2wv_df.columns
# Out:
# Index(['GeoFIPS', 'GeoName', 'Region', 'TableName', 'LineCode',
#        'IndustryClassification', 'Description', 'Unit', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype='object')
